# %%
import requests
import pandas as pd
import datetime
import time

# 🔹 Replace with your actual NewsAPI key
API_KEY = "565ade5d80694d418b85a9bd8bcfc7c5"

# 🔹 Trusted news sources
TRUSTED_SOURCES = ["cnn", "espn", "abc-news", "google-news"]

# 🔹 List to store all news articles
all_news = []

# 🔹 Fetch news over a wider date range
for source in TRUSTED_SOURCES:
    print(f"Fetching news from: {source}")

    for days_ago in range(0, 20):  # Fetch 20 different days (100 articles per day)
        date = (datetime.datetime.today() - datetime.timedelta(days=days_ago)).strftime('%Y-%m-%d')

        url = f"https://newsapi.org/v2/everything?sources={source}&from={date}&to={date}&pageSize=100&language=en&apiKey={API_KEY}"

        response = requests.get(url)
        data = response.json()

        if data["status"] == "ok":
            for article in data["articles"]:
                all_news.append({
                    "source_id": article["source"].get("id", "N/A"),
                    "source_name": article["source"]["name"],
                    "author": article.get("author", "N/A"),
                    "title": article["title"],
                    "description": article.get("description", "N/A"),
                    "url": article["url"],
                    "urlToImage": article.get("urlToImage", "N/A"),
                    "publishedAt": article["publishedAt"],
                    "content": article.get("content", "N/A")
                })
        else:
            print(f"❌ Error fetching news from {source} on {date}: {data}")

        time.sleep(1)  # Sleep to avoid API rate limits

# 🔹 Convert to DataFrame
df = pd.DataFrame(all_news)

# 🔹 Save to CSV file
df.to_csv("trusted_news_8000.csv", index=False)

print("✅ Successfully saved news articles to trusted_news_8000.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-3b39c7aec0f8> in <cell line: 0>()
#       1 import requests
# ----> 2 import pandas as pd
#       3 import datetime
#       4 import time
#       5
#
# /usr/local/lib/python3.11/dist-packages/pandas/__init__.py in <module>
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      48
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/api.py in <module>
#      45 from pandas.core.construction import array
#      46 from pandas.core.flags import Flags
# ---> 47 from pandas.core.groupby import (
#      48     Grouper,
#      49     NamedAgg,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/__init__.py in <module>
# ----> 1 from pandas.core.groupby.generic import (
# ...
